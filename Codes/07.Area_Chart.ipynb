# %% [markdown]
# # Area Chart
# ### 1.Area Chart shows graphically quantitative data
# ### 2.Fill the area between axis and line graph colors or textures
# ### 3.Used to show changes in various data over time
# ### 4.There are two functions to Plot area chart : fill_between() and stackplot()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Days=[1, 2, 3, 4, 5, 6, 7]
Total_Sales=[20, 40, 30, 10, 25, 60, 120]
fig=plt.figure(figsize=(10, 5))
plt.fill_between(Days, Total_Sales)
plt.show()

# %%
Days=[1, 2, 3, 4, 5, 6, 7]
Ram_Sales=[20, 40, 30, 10, 25, 60, 120]
Shyam_Sales=[56, 78, 454, 34, 23, 90, 53]
Rakesh_Sales=[45, 89, 34, 12, 86, 543, 34]
fig=plt.figure(figsize=(10, 5))
plt.stackplot(Days, Ram_Sales, Shyam_Sales, Rakesh_Sales, labels=['Ram', 'Shyam', 'Rakesh'])
plt.legend()
plt.show()
