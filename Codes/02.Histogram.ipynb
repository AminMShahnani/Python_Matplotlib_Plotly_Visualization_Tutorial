# %% [markdown]
# ## Histogram
# ### Histogram is uset to represent the frequency distibution with continous classes.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Age=[34, 23, 56, 45, 32, 21, 67, 89, 65, 43, 21, 93, 18, 10, 31, 96, 18, 28, 100, 59]
fig=plt.figure(figsize=(10, 5)) #Width and height of figure in inches
plt.hist(Age, bins=10, color='b', edgecolor='r')
plt.show()

# %%
Age=[34, 23, 56, 45, 32, 21, 67, 89, 65, 43, 21, 93, 18, 10, 31, 96, 18, 28, 100, 59]
Height=[134, 123, 156, 145, 132, 121, 167, 189, 165, 143, 121, 193, 18, 15, 131, 196, 118, 128, 147, 159]
fig=plt.figure(figsize=(10, 5)) #Width and height of figure in inches
S1=plt.subplot(211)
S2=plt.subplot(212)
S1.set(title='Age Distribution')
S2.set(title='Height Distribution')
S1.hist(Age, bins=10, color='b', edgecolor='r')
S2.hist(Height, bins=10, color='g', edgecolor='r')
plt.show()

# %%
Age=[34, 23, 56, 45, 32, 21, 67, 89, 65, 43, 21, 93, 18, 10, 31, 96, 18, 28, 100, 59]
Height=[134, 123, 156, 145, 132, 121, 167, 189, 165, 143, 121, 193, 18, 15, 131, 196, 118, 128, 147, 159]
fig=plt.figure(figsize=(10, 5)) #Width and height of figure in inches
S1=plt.subplot(211)
S2=plt.subplot(212)
S1.set(title='Age Distribution')
S2.set(title='Height Distribution')
S1.hist(Age, bins=10, color='b', edgecolor='r', linewidth=3)
S2.hist(Height, bins=10, color='g', edgecolor='r')
plt.show()
